# %% [markdown]
# # SW Card Hunter — Marktanalyse
#
# Dieses Notebook dient für manuelle Analysen und Experimente.

# %%
import sys
sys.path.insert(0, '../src')

import sqlite3
import pandas as pd

conn = sqlite3.connect('../data/cards.db')
print('Datenbank verbunden')
